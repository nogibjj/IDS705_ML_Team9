# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_recall_curve
import os

# %%
# !pip install tensorflow
# !pip install keras
# !pip install torch
# !pip install h5py
# Out:
# Requirement already satisfied: tensorflow in /usr/local/python/3.10.4/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (4.22.3)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.10/site-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/codespace/.local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /home/codespace/.local/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/codespace/.local/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: keras in /usr/local/python/3.10.4/lib/python3.10/site-packages (2.12.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: torch in /home/codespace/.local/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from torch) (3.0)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.10/site-packages (from torch) (1.11.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from torch) (3.10.7)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: triton==2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.6.1)
# Requirement already satisfied: wheel in /home/codespace/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Requirement already satisfied: cmake in /home/codespace/.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (3.26.1)
# Requirement already satisfied: lit in /home/codespace/.local/lib/python3.10/site-packages (from triton==2.0.0->torch) (16.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/codespace/.local/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: h5py in /usr/local/python/3.10.4/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from h5py) (1.23.5)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
model_rgb_path = "/workspaces/IDS705_ML_Team9/deploy_resnet_model_140K_alldata_rgb_weights.h5"
weights_rgb_path = "/workspaces/IDS705_ML_Team9/deploy_resnet_model_140K_alldata_rgb_weights.h5"

# load the model using h5py
import h5py
model_rgb = h5py.File(model_rgb_path, 'r')
model_rgb_weights = h5py.File(weights_rgb_path, 'r')

# load the model using keras
from keras.models import model_from_json
import tensorflow.keras as keras

# Load the h5 model file
model = keras.models.load_model(model_rgb_path)

# Print the model summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[34], line 6
#       4 # load the model using h5py
#       5 import h5py
# ----> 6 model_rgb = h5py.File(model_rgb_path, 'r')
#       7 model_rgb_weights = h5py.File(weights_rgb_path, 'r')
#       9 # load the model using keras
#
# File ~/.python/current/lib/python3.10/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File ~/.python/current/lib/python3.10/site-packages/h5py/_hl/files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# OSError: Unable to open file (truncated file: eof = 94830592, sblock->base_addr = 0, stored_eof = 98793008)

# %%
test = Image.load_img("/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Aditya-John-400x400.jpeg", target_size=(256, 256))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 test = Image.load_img("/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Aditya-John-400x400.jpeg", target_size=(256, 256))
#
# File ~/.local/lib/python3.10/site-packages/PIL/Image.py:79, in __getattr__(name)
#      77     return Resampling[old_resampling[name]]
#      78 msg = f"module '{__name__}' has no attribute '{name}'"
# ---> 79 raise AttributeError(msg)
#
# AttributeError: module 'PIL.Image' has no attribute 'load_img'

# %%
from PIL import Image
def pre_process_image_data(path):
    for i in os.listdir(path):
        if i.endswith(".jpg"):
            # load the image and resize to 256 by 256
            img = Image.load_img(path + i, target_size=(256, 256))
            # save it to the same folder and overwrite the original
            img.save(path + i)
        elif i.endswith(".png"):
            # load the image and resize to 256 by 256
            img = Image.load_img(path + i, target_size=(256, 256))
            # save it to the same folder and overwrite the original
            img.save(path + i)

        elif i.endswith(".jpeg"):
            # load the image and resize to 256 by 256
            img = Image.load_img(path + i, target_size=(256, 256))
            # save it to the same folder and overwrite the original
            img.save(path + i)

# %%
test = '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Yuanjing-Zhu-400x400.jpeg'
test = Image.open(test)
test = np.array(test)
test
# Out:
# array([[[111, 109, 114],
#         [111, 109, 114],
#         [111, 109, 114],
#         ...,
#         [113, 111, 114],
#         [113, 111, 114],
#         [113, 111, 114]],
#
#        [[111, 109, 114],
#         [111, 109, 114],
#         [112, 110, 115],
#         ...,
#         [113, 111, 114],
#         [113, 111, 114],
#         [113, 111, 114]],
#
#        [[111, 109, 114],
#         [112, 110, 115],
#         [112, 110, 115],
#         ...,
#         [113, 111, 114],
#         [113, 111, 114],
#         [113, 111, 114]],
#
#        ...,
#
#        [[ 19,  23,  35],
#         [ 20,  24,  36],
#         [ 21,  25,  37],
#         ...,
#         [ 15,  24,  33],
#         [ 19,  28,  37],
#         [ 26,  35,  44]],
#
#        [[ 19,  23,  35],
#         [ 20,  24,  36],
#         [ 22,  26,  38],
#         ...,
#         [ 15,  24,  33],
#         [ 18,  27,  36],
#         [ 25,  34,  43]],
#
#        [[ 19,  23,  35],
#         [ 20,  24,  36],
#         [ 22,  26,  38],
#         ...,
#         [ 15,  24,  33],
#         [ 18,  27,  36],
#         [ 25,  34,  43]]], dtype=uint8)

# %% [markdown]
# ## function for resize and store a list of array

# %%
from PIL import Image
def pre_process_image_data(path):
    lst_img = []
    for i in os.listdir(path):
        # print(i)
        if i[-4:] == "jpeg":
        # print(path + str('/' + i))
            with open(path + str('/' + i), 'rb') as f:
                img = Image.open(f)
                # resize the image to 256 by 256
                img = img.resize((256, 256))
                # save it to the same folder and overwrite the original
                img.save(path + str('/' + i))
                # print("saved")
                # store their array in a list
                lst_img.append(np.array(img))
    return lst_img
            

# def get_array(path):
#     lst_img = []
#     for i in os.listdir(path):

#         if i[-4:] == "jpeg":
#         # print(path + str('/' + i))
#             with open(path + str('/' + i), 'rb') as f:
#                 img = Image.open(f)
#                 # resize the image to 256 by 256
#                 img = img.resize((256, 256))
#                 # save it to the same folder and overwrite the original
#                 img.save(path + str('/' + i))
#                 # print("saved")
#                 # store their array in a list
#                 lst_img.append(np.array(img))
#     return lst_img

# pre_process_image_data(mids24_path)

# # check the resolution of the image
# test = '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Yuanjing-Zhu-400x400.jpeg'
# test = Image.open(test)
# # check the resolution of the image
# test.size

# %% [markdown]
# ## Process the mids24

# %%
# mids24 prediction
mids24_path = "/workspaces/IDS705_ML_Team9/Data/Application/MIDS24"

# use the model to predict the mids24 data: image data
import PIL
from PIL import Image
import os
import numpy as np

# load the image data
pre_process_image_data(mids24_path)
# Out:
# [array([[[111, 109, 114],
#          [111, 109, 114],
#          [111, 109, 114],
#          ...,
#          [113, 111, 114],
#          [113, 111, 114],
#          [113, 111, 114]],
#
#         [[111, 109, 114],
#          [111, 109, 114],
#          [112, 110, 115],
#          ...,
#          [113, 111, 114],
#          [113, 111, 114],
#          [113, 111, 114]],
#
#         [[111, 109, 114],
#          [112, 110, 115],
#          [112, 110, 115],
#          ...,
#          [113, 111, 114],
#          [113, 111, 114],
#          [113, 111, 114]],
#
#         ...,
#
#         [[ 19,  23,  35],
#          [ 20,  24,  36],
#          [ 21,  25,  37],
#          ...,
#          [ 15,  24,  33],
#          [ 19,  28,  37],
#          [ 26,  35,  44]],
#
#         [[ 19,  23,  35],
#          [ 20,  24,  36],
#          [ 22,  26,  38],
#          ...,
#          [ 15,  24,  33],
#          [ 18,  27,  36],
#          [ 25,  34,  43]],
#
#         [[ 19,  23,  35],
#          [ 20,  24,  36],
#          [ 22,  26,  38],
#          ...,
#          [ 15,  24,  33],
#          [ 18,  27,  36],
#          [ 25,  34,  43]]], dtype=uint8),
#  array([[[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         ...,
#
#         [[151, 143, 141],
#          [148, 140, 137],
#          [144, 134, 132],
#          ...,
#          [139, 132, 139],
#          [140, 130, 139],
#          [142, 135, 143]],
#
#         [[158, 148, 146],
#          [143, 134, 129],
#          [122, 111, 107],
#          ...,
#          [140, 130, 138],
#          [141, 129, 139],
#          [144, 134, 143]],
#
#         [[151, 142, 137],
#          [125, 116, 111],
#          [ 89,  78,  74],
#          ...,
#          [141, 130, 138],
#          [140, 128, 138],
#          [146, 134, 144]]], dtype=uint8),
#  array([[[ 87,  85,  88],
#          [ 87,  85,  88],
#          [ 87,  85,  88],
#          ...,
#          [ 97,  95,  96],
#          [ 97,  95,  96],
#          [ 97,  95,  96]],
#
#         [[ 87,  85,  88],
#          [ 87,  85,  88],
#          [ 88,  86,  89],
#          ...,
#          [ 97,  95,  96],
#          [ 97,  95,  96],
#          [ 97,  95,  96]],
#
#         [[ 88,  86,  89],
#          [ 88,  86,  89],
#          [ 88,  86,  89],
#          ...,
#          [ 97,  95,  96],
#          [ 97,  95,  96],
#          [ 97,  95,  96]],
#
#         ...,
#
#         [[142, 138, 135],
#          [164, 161, 156],
#          [189, 186, 179],
#          ...,
#          [244, 243, 238],
#          [247, 246, 241],
#          [245, 244, 239]],
#
#         [[146, 143, 138],
#          [178, 175, 170],
#          [193, 190, 183],
#          ...,
#          [244, 243, 238],
#          [248, 247, 242],
#          [244, 243, 238]],
#
#         [[150, 147, 142],
#          [188, 185, 180],
#          [195, 192, 185],
#          ...,
#          [245, 244, 239],
#          [248, 247, 242],
#          [243, 242, 237]]], dtype=uint8),
#  array([[[ 92,  90,  95],
#          [ 92,  90,  95],
#          [ 92,  90,  95],
#          ...,
#          [ 95,  95,  97],
#          [ 95,  95,  97],
#          [ 95,  95,  97]],
#
#         [[ 92,  90,  95],
#          [ 92,  90,  95],
#          [ 92,  90,  95],
#          ...,
#          [ 96,  96,  98],
#          [ 95,  95,  97],
#          [ 95,  95,  97]],
#
#         [[ 92,  90,  95],
#          [ 92,  90,  95],
#          [ 92,  90,  95],
#          ...,
#          [ 96,  96,  98],
#          [ 96,  96,  98],
#          [ 95,  95,  97]],
#
#         ...,
#
#         [[151, 144, 151],
#          [151, 144, 151],
#          [150, 145, 151],
#          ...,
#          [ 24,  27,  42],
#          [ 23,  26,  41],
#          [ 23,  26,  41]],
#
#         [[151, 144, 151],
#          [151, 144, 151],
#          [150, 145, 151],
#          ...,
#          [ 22,  25,  40],
#          [ 22,  25,  40],
#          [ 22,  25,  40]],
#
#         [[151, 144, 151],
#          [151, 144, 151],
#          [150, 145, 151],
#          ...,
#          [ 22,  25,  40],
#          [ 22,  25,  40],
#          [ 22,  25,  40]]], dtype=uint8),
#  array([[[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96]],
#
#         [[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 96,  94,  97],
#          [ 96,  94,  97],
#          [ 96,  94,  97]],
#
#         [[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 97,  95,  98],
#          [ 97,  95,  98],
#          [ 97,  95,  98]],
#
#         ...,
#
#         [[137, 135, 138],
#          [131, 129, 132],
#          [137, 135, 138],
#          ...,
#          [ 28,  26,  29],
#          [ 48,  46,  51],
#          [ 94,  92,  97]],
#
#         [[139, 137, 140],
#          [129, 127, 130],
#          [137, 135, 138],
#          ...,
#          [ 39,  37,  40],
#          [ 46,  44,  49],
#          [ 73,  71,  76]],
#
#         [[141, 139, 142],
#          [129, 127, 130],
#          [137, 135, 138],
#          ...,
#          [ 64,  62,  65],
#          [ 58,  56,  61],
#          [ 43,  41,  46]]], dtype=uint8),
#  array([[[ 98,  96, 101],
#          [ 98,  96, 101],
#          [ 98,  96, 101],
#          ...,
#          [101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102]],
#
#         [[ 98,  96, 101],
#          [ 98,  96, 101],
#          [ 98,  96, 101],
#          ...,
#          [101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102]],
#
#         [[ 98,  96, 101],
#          [ 98,  96, 101],
#          [ 98,  96, 101],
#          ...,
#          [101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102]],
#
#         ...,
#
#         [[162, 174, 186],
#          [163, 175, 187],
#          [165, 177, 189],
#          ...,
#          [128, 140, 154],
#          [127, 139, 153],
#          [123, 135, 149]],
#
#         [[160, 172, 184],
#          [163, 175, 187],
#          [165, 177, 189],
#          ...,
#          [126, 138, 152],
#          [125, 137, 151],
#          [120, 132, 146]],
#
#         [[159, 171, 183],
#          [162, 174, 186],
#          [164, 176, 188],
#          ...,
#          [125, 137, 151],
#          [123, 135, 149],
#          [118, 130, 144]]], dtype=uint8),
#  array([[[100,  98, 101],
#          [100,  98, 101],
#          [100,  98, 101],
#          ...,
#          [104, 102, 103],
#          [104, 102, 103],
#          [104, 102, 103]],
#
#         [[100,  98, 101],
#          [100,  98, 101],
#          [101,  99, 102],
#          ...,
#          [104, 102, 103],
#          [104, 102, 103],
#          [104, 102, 103]],
#
#         [[100,  98, 101],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [104, 102, 103],
#          [104, 102, 103],
#          [104, 102, 103]],
#
#         ...,
#
#         [[ 15,  15,  15],
#          [ 15,  15,  15],
#          [ 15,  15,  15],
#          ...,
#          [  5,   3,   4],
#          [ 20,  18,  19],
#          [ 55,  53,  54]],
#
#         [[ 15,  15,  15],
#          [ 15,  15,  15],
#          [ 15,  15,  15],
#          ...,
#          [  9,   7,   8],
#          [  8,   6,   7],
#          [ 26,  24,  25]],
#
#         [[ 15,  15,  15],
#          [ 15,  15,  15],
#          [ 15,  15,  15],
#          ...,
#          [ 14,  12,  13],
#          [  6,   4,   5],
#          [ 13,  11,  12]]], dtype=uint8),
#  array([[[ 97,  95, 100],
#          [ 97,  95, 100],
#          [ 97,  95, 100],
#          ...,
#          [106, 104, 107],
#          [106, 104, 107],
#          [106, 104, 107]],
#
#         [[ 97,  95, 100],
#          [ 97,  95, 100],
#          [ 98,  96, 101],
#          ...,
#          [106, 104, 107],
#          [106, 104, 107],
#          [106, 104, 107]],
#
#         [[ 98,  96, 101],
#          [ 98,  96, 101],
#          [ 98,  96, 101],
#          ...,
#          [106, 104, 107],
#          [106, 104, 107],
#          [106, 104, 107]],
#
#         ...,
#
#         [[125, 123, 128],
#          [126, 124, 129],
#          [126, 124, 129],
#          ...,
#          [147, 146, 144],
#          [114, 112, 115],
#          [115, 113, 116]],
#
#         [[125, 123, 128],
#          [126, 124, 129],
#          [126, 124, 129],
#          ...,
#          [148, 147, 145],
#          [114, 112, 115],
#          [115, 113, 116]],
#
#         [[125, 123, 128],
#          [126, 124, 129],
#          [126, 124, 129],
#          ...,
#          [148, 147, 145],
#          [114, 112, 115],
#          [115, 113, 116]]], dtype=uint8),
#  array([[[ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          ...,
#          [ 99,  97, 100],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[100,  98, 101],
#          [100,  98, 101],
#          [100,  98, 101],
#          ...,
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 98,  96,  99]],
#
#         ...,
#
#         [[ 15,  19,  28],
#          [ 18,  22,  31],
#          [ 22,  26,  35],
#          ...,
#          [ 30,  37,  45],
#          [ 35,  42,  50],
#          [ 30,  37,  45]],
#
#         [[ 13,  17,  26],
#          [ 16,  20,  29],
#          [ 20,  24,  33],
#          ...,
#          [ 27,  34,  42],
#          [ 34,  41,  49],
#          [ 28,  35,  43]],
#
#         [[ 12,  16,  25],
#          [ 14,  18,  27],
#          [ 18,  22,  31],
#          ...,
#          [ 25,  32,  40],
#          [ 33,  40,  48],
#          [ 28,  35,  43]]], dtype=uint8),
#  array([[[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105]],
#
#         ...,
#
#         [[ 16,  16,  18],
#          [ 16,  16,  18],
#          [ 15,  15,  17],
#          ...,
#          [ 64,  63,  68],
#          [114, 113, 118],
#          [138, 137, 142]],
#
#         [[ 15,  15,  17],
#          [ 15,  15,  17],
#          [ 14,  14,  16],
#          ...,
#          [ 49,  48,  53],
#          [ 96,  95, 100],
#          [134, 133, 138]],
#
#         [[ 15,  15,  17],
#          [ 14,  14,  16],
#          [ 14,  14,  16],
#          ...,
#          [ 38,  37,  42],
#          [ 84,  83,  88],
#          [129, 128, 133]]], dtype=uint8),
#  array([[[ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         ...,
#
#         [[137, 136, 142],
#          [138, 137, 143],
#          [139, 137, 142],
#          ...,
#          [146, 166, 175],
#          [142, 162, 171],
#          [138, 158, 167]],
#
#         [[137, 136, 142],
#          [137, 136, 142],
#          [139, 137, 142],
#          ...,
#          [146, 166, 175],
#          [143, 163, 172],
#          [140, 160, 169]],
#
#         [[137, 136, 142],
#          [137, 136, 142],
#          [138, 136, 141],
#          ...,
#          [146, 166, 175],
#          [143, 163, 172],
#          [140, 160, 169]]], dtype=uint8),
#  array([[[ 94,  92,  95],
#          [ 94,  92,  95],
#          [ 94,  92,  95],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 94,  92,  95],
#          [ 94,  92,  95],
#          [ 94,  92,  95],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 94,  92,  95],
#          [ 94,  92,  95],
#          [ 94,  92,  95],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         ...,
#
#         [[140, 135, 141],
#          [140, 135, 141],
#          [140, 135, 141],
#          ...,
#          [ 22,  23,  28],
#          [ 21,  22,  27],
#          [ 20,  21,  26]],
#
#         [[140, 135, 141],
#          [140, 135, 141],
#          [140, 135, 141],
#          ...,
#          [ 22,  23,  28],
#          [ 21,  22,  27],
#          [ 20,  21,  26]],
#
#         [[140, 135, 141],
#          [140, 135, 141],
#          [140, 135, 141],
#          ...,
#          [ 23,  24,  29],
#          [ 21,  22,  27],
#          [ 20,  21,  26]]], dtype=uint8),
#  array([[[ 89,  87,  92],
#          [ 90,  88,  93],
#          [ 91,  89,  94],
#          ...,
#          [ 96,  94,  97],
#          [ 96,  94,  97],
#          [ 96,  94,  97]],
#
#         [[ 89,  87,  92],
#          [ 90,  88,  93],
#          [ 91,  89,  94],
#          ...,
#          [ 97,  95,  98],
#          [ 96,  94,  97],
#          [ 96,  94,  97]],
#
#         [[ 90,  88,  93],
#          [ 90,  88,  93],
#          [ 91,  89,  94],
#          ...,
#          [ 97,  95,  98],
#          [ 97,  95,  98],
#          [ 96,  94,  97]],
#
#         ...,
#
#         [[161, 132, 102],
#          [161, 132, 102],
#          [161, 132, 102],
#          ...,
#          [119, 117, 120],
#          [119, 117, 120],
#          [119, 117, 120]],
#
#         [[160, 131, 101],
#          [160, 131, 101],
#          [160, 131, 101],
#          ...,
#          [119, 117, 120],
#          [119, 117, 120],
#          [119, 117, 120]],
#
#         [[160, 131, 101],
#          [160, 131, 101],
#          [160, 131, 101],
#          ...,
#          [119, 117, 120],
#          [119, 117, 120],
#          [119, 117, 120]]], dtype=uint8),
#  array([[[ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          ...,
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100]],
#
#         [[ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          ...,
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100]],
#
#         [[ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          ...,
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100]],
#
#         ...,
#
#         [[138, 133, 137],
#          [138, 133, 137],
#          [138, 133, 137],
#          ...,
#          [136, 134, 137],
#          [136, 134, 137],
#          [136, 134, 137]],
#
#         [[138, 133, 137],
#          [138, 133, 137],
#          [138, 133, 137],
#          ...,
#          [136, 134, 137],
#          [136, 134, 137],
#          [136, 134, 137]],
#
#         [[138, 133, 137],
#          [138, 133, 137],
#          [138, 133, 137],
#          ...,
#          [136, 134, 137],
#          [136, 134, 137],
#          [136, 134, 137]]], dtype=uint8),
#  array([[[103, 101, 104],
#          [103, 101, 104],
#          [103, 101, 104],
#          ...,
#          [105, 103, 106],
#          [105, 103, 106],
#          [105, 103, 106]],
#
#         [[103, 101, 104],
#          [103, 101, 104],
#          [103, 101, 104],
#          ...,
#          [105, 103, 106],
#          [105, 103, 106],
#          [105, 103, 106]],
#
#         [[103, 101, 104],
#          [103, 101, 104],
#          [103, 101, 104],
#          ...,
#          [105, 103, 106],
#          [105, 103, 106],
#          [105, 103, 106]],
#
#         ...,
#
#         [[135, 130, 134],
#          [135, 130, 134],
#          [135, 130, 134],
#          ...,
#          [124, 124, 126],
#          [124, 124, 126],
#          [124, 124, 126]],
#
#         [[135, 130, 134],
#          [135, 130, 134],
#          [135, 130, 134],
#          ...,
#          [124, 124, 126],
#          [124, 124, 126],
#          [124, 124, 126]],
#
#         [[135, 130, 134],
#          [135, 130, 134],
#          [135, 130, 134],
#          ...,
#          [124, 124, 126],
#          [124, 124, 126],
#          [124, 124, 126]]], dtype=uint8),
#  array([[[102, 100, 105],
#          [102, 100, 105],
#          [102, 100, 105],
#          ...,
#          [105, 103, 106],
#          [105, 103, 106],
#          [105, 103, 106]],
#
#         [[102, 100, 105],
#          [102, 100, 105],
#          [103, 101, 106],
#          ...,
#          [106, 104, 107],
#          [105, 103, 106],
#          [105, 103, 106]],
#
#         [[102, 100, 105],
#          [103, 101, 106],
#          [103, 101, 106],
#          ...,
#          [106, 104, 107],
#          [106, 104, 107],
#          [105, 103, 106]],
#
#         ...,
#
#         [[146, 135, 139],
#          [146, 135, 139],
#          [144, 135, 140],
#          ...,
#          [131, 121, 130],
#          [133, 121, 133],
#          [134, 122, 134]],
#
#         [[147, 135, 137],
#          [146, 135, 139],
#          [144, 135, 140],
#          ...,
#          [131, 121, 130],
#          [133, 121, 133],
#          [133, 121, 133]],
#
#         [[147, 135, 137],
#          [146, 136, 137],
#          [144, 135, 140],
#          ...,
#          [131, 121, 130],
#          [132, 120, 132],
#          [133, 121, 133]]], dtype=uint8),
#  array([[[102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103],
#          ...,
#          [110, 106, 105],
#          [110, 106, 105],
#          [110, 106, 105]],
#
#         [[102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103],
#          ...,
#          [111, 107, 106],
#          [110, 106, 105],
#          [110, 106, 105]],
#
#         [[102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103],
#          ...,
#          [111, 107, 106],
#          [111, 107, 106],
#          [110, 106, 105]],
#
#         ...,
#
#         [[217, 209, 206],
#          [218, 210, 207],
#          [220, 212, 209],
#          ...,
#          [227, 226, 222],
#          [228, 227, 223],
#          [235, 234, 230]],
#
#         [[218, 210, 207],
#          [218, 210, 207],
#          [219, 211, 208],
#          ...,
#          [225, 224, 220],
#          [233, 232, 228],
#          [245, 244, 240]],
#
#         [[219, 211, 208],
#          [218, 210, 207],
#          [218, 210, 207],
#          ...,
#          [226, 225, 221],
#          [240, 239, 235],
#          [254, 253, 249]]], dtype=uint8),
#  array([[[103, 101, 106],
#          [103, 101, 106],
#          [103, 101, 106],
#          ...,
#          [104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105]],
#
#         [[103, 101, 106],
#          [103, 101, 106],
#          [103, 101, 106],
#          ...,
#          [104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105]],
#
#         [[103, 101, 106],
#          [103, 101, 106],
#          [103, 101, 106],
#          ...,
#          [104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105]],
#
#         ...,
#
#         [[208, 199, 190],
#          [209, 200, 191],
#          [210, 201, 192],
#          ...,
#          [230, 229, 225],
#          [224, 223, 219],
#          [221, 220, 216]],
#
#         [[208, 199, 190],
#          [209, 200, 191],
#          [210, 201, 192],
#          ...,
#          [226, 225, 221],
#          [214, 213, 209],
#          [212, 211, 207]],
#
#         [[209, 200, 191],
#          [209, 200, 191],
#          [210, 201, 192],
#          ...,
#          [222, 221, 217],
#          [207, 206, 202],
#          [205, 204, 200]]], dtype=uint8),
#  array([[[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [106, 104, 105],
#          [106, 104, 105],
#          [107, 105, 106]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [106, 104, 105],
#          [106, 104, 105],
#          [107, 105, 106]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [106, 104, 105],
#          [106, 104, 105],
#          [107, 105, 106]],
#
#         ...,
#
#         [[ 17,  17,  27],
#          [ 18,  18,  28],
#          [ 18,  18,  28],
#          ...,
#          [139, 137, 140],
#          [139, 134, 138],
#          [138, 133, 137]],
#
#         [[ 17,  17,  27],
#          [ 18,  18,  28],
#          [ 18,  18,  28],
#          ...,
#          [140, 138, 141],
#          [141, 136, 140],
#          [139, 134, 138]],
#
#         [[ 17,  17,  27],
#          [ 18,  18,  28],
#          [ 18,  18,  28],
#          ...,
#          [141, 139, 142],
#          [141, 136, 140],
#          [140, 135, 139]]], dtype=uint8),
#  array([[[ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 96,  94,  97],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 95,  93,  96],
#          [ 96,  94,  97],
#          [ 96,  94,  97],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         ...,
#
#         [[ 49,  48,  44],
#          [ 47,  46,  42],
#          [ 44,  43,  39],
#          ...,
#          [124, 122, 125],
#          [124, 122, 125],
#          [124, 122, 125]],
#
#         [[ 49,  48,  44],
#          [ 46,  45,  41],
#          [ 43,  42,  38],
#          ...,
#          [124, 122, 125],
#          [124, 122, 125],
#          [124, 122, 125]],
#
#         [[ 52,  51,  47],
#          [ 49,  48,  44],
#          [ 46,  45,  41],
#          ...,
#          [124, 122, 125],
#          [124, 122, 125],
#          [124, 122, 125]]], dtype=uint8),
#  array([[[94, 92, 95],
#          [94, 92, 95],
#          [94, 92, 95],
#          ...,
#          [96, 94, 97],
#          [96, 94, 97],
#          [96, 94, 97]],
#
#         [[94, 92, 95],
#          [94, 92, 95],
#          [94, 92, 95],
#          ...,
#          [96, 94, 97],
#          [96, 94, 97],
#          [96, 94, 97]],
#
#         [[94, 92, 95],
#          [94, 92, 95],
#          [94, 92, 95],
#          ...,
#          [96, 94, 97],
#          [96, 94, 97],
#          [96, 94, 97]],
#
#         ...,
#
#         [[11, 11, 11],
#          [11, 11, 11],
#          [11, 11, 11],
#          ...,
#          [12, 12, 12],
#          [12, 12, 12],
#          [10, 10, 10]],
#
#         [[11, 11, 11],
#          [11, 11, 11],
#          [11, 11, 11],
#          ...,
#          [11, 11, 11],
#          [11, 11, 11],
#          [10, 10, 10]],
#
#         [[11, 11, 11],
#          [11, 11, 11],
#          [11, 11, 11],
#          ...,
#          [11, 11, 11],
#          [11, 11, 11],
#          [10, 10, 10]]], dtype=uint8),
#  array([[[100,  98, 101],
#          [100,  98, 101],
#          [100,  98, 101],
#          ...,
#          [102, 100, 101],
#          [102, 100, 101],
#          [102, 100, 101]],
#
#         [[100,  98, 101],
#          [100,  98, 101],
#          [100,  98, 101],
#          ...,
#          [102, 100, 101],
#          [102, 100, 101],
#          [102, 100, 101]],
#
#         [[100,  98, 101],
#          [100,  98, 101],
#          [100,  98, 101],
#          ...,
#          [102, 100, 101],
#          [102, 100, 101],
#          [102, 100, 101]],
#
#         ...,
#
#         [[ 25,  23,  26],
#          [ 25,  23,  26],
#          [ 25,  23,  26],
#          ...,
#          [ 35,  33,  36],
#          [ 35,  33,  36],
#          [ 35,  33,  36]],
#
#         [[ 25,  23,  26],
#          [ 25,  23,  26],
#          [ 25,  23,  26],
#          ...,
#          [ 35,  33,  36],
#          [ 34,  32,  35],
#          [ 34,  32,  35]],
#
#         [[ 25,  23,  26],
#          [ 25,  23,  26],
#          [ 25,  23,  26],
#          ...,
#          [ 34,  32,  35],
#          [ 34,  32,  35],
#          [ 34,  32,  35]]], dtype=uint8),
#  array([[[107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108],
#          ...,
#          [121, 117, 118],
#          [121, 117, 118],
#          [121, 117, 118]],
#
#         [[107, 105, 108],
#          [107, 105, 108],
#          [108, 106, 109],
#          ...,
#          [121, 117, 118],
#          [121, 117, 118],
#          [121, 117, 118]],
#
#         [[107, 105, 108],
#          [108, 106, 109],
#          [108, 106, 109],
#          ...,
#          [121, 117, 118],
#          [121, 117, 118],
#          [121, 117, 118]],
#
#         ...,
#
#         [[135, 129, 129],
#          [135, 129, 129],
#          [135, 129, 131],
#          ...,
#          [243, 207, 181],
#          [242, 206, 180],
#          [241, 205, 179]],
#
#         [[134, 128, 128],
#          [134, 128, 128],
#          [134, 128, 130],
#          ...,
#          [242, 205, 179],
#          [242, 205, 179],
#          [241, 204, 178]],
#
#         [[134, 128, 128],
#          [134, 128, 128],
#          [134, 128, 130],
#          ...,
#          [242, 205, 179],
#          [241, 204, 178],
#          [240, 203, 177]]], dtype=uint8),
#  array([[[100,  98, 101],
#          [100,  98, 101],
#          [100,  98, 101],
#          ...,
#          [100,  98, 101],
#          [100,  98, 101],
#          [100,  98, 101]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [101,  99, 102],
#          [100,  98, 101],
#          [100,  98, 101]],
#
#         [[102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103],
#          ...,
#          [101,  99, 102],
#          [101,  99, 102],
#          [100,  98, 101]],
#
#         ...,
#
#         [[109, 108, 106],
#          [ 75,  74,  72],
#          [ 59,  58,  56],
#          ...,
#          [104, 103,  99],
#          [104, 103,  99],
#          [103, 102,  98]],
#
#         [[101, 100,  98],
#          [ 67,  66,  64],
#          [ 58,  57,  55],
#          ...,
#          [ 99,  98,  94],
#          [ 98,  97,  95],
#          [ 97,  96,  94]],
#
#         [[ 95,  94,  92],
#          [ 62,  61,  59],
#          [ 58,  57,  55],
#          ...,
#          [ 93,  92,  88],
#          [ 91,  90,  88],
#          [ 90,  89,  87]]], dtype=uint8),
#  array([[[ 87,  85,  88],
#          [ 87,  85,  88],
#          [ 87,  85,  88],
#          ...,
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100]],
#
#         [[ 87,  85,  88],
#          [ 87,  85,  88],
#          [ 88,  86,  89],
#          ...,
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100]],
#
#         [[ 88,  86,  89],
#          [ 88,  86,  89],
#          [ 88,  86,  89],
#          ...,
#          [ 99,  97, 100],
#          [ 99,  97, 100],
#          [ 99,  97, 100]],
#
#         ...,
#
#         [[137, 135, 140],
#          [125, 123, 128],
#          [137, 135, 138],
#          ...,
#          [ 20,  19,  15],
#          [ 20,  19,  15],
#          [ 21,  20,  16]],
#
#         [[134, 132, 137],
#          [126, 124, 129],
#          [134, 132, 135],
#          ...,
#          [ 20,  19,  15],
#          [ 20,  19,  15],
#          [ 20,  19,  15]],
#
#         [[132, 130, 135],
#          [126, 124, 129],
#          [132, 130, 133],
#          ...,
#          [ 19,  18,  14],
#          [ 19,  18,  14],
#          [ 20,  19,  15]]], dtype=uint8),
#  array([[[106, 104, 107],
#          [106, 104, 107],
#          [106, 104, 107],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[106, 104, 107],
#          [106, 104, 107],
#          [106, 104, 107],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[106, 104, 107],
#          [106, 104, 107],
#          [106, 104, 107],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         ...,
#
#         [[138, 138, 140],
#          [139, 139, 141],
#          [139, 139, 141],
#          ...,
#          [135, 133, 136],
#          [134, 132, 137],
#          [137, 135, 140]],
#
#         [[138, 138, 140],
#          [139, 139, 141],
#          [139, 139, 141],
#          ...,
#          [134, 132, 135],
#          [134, 132, 137],
#          [138, 136, 141]],
#
#         [[138, 138, 140],
#          [139, 139, 141],
#          [139, 139, 141],
#          ...,
#          [134, 132, 135],
#          [134, 132, 137],
#          [139, 137, 142]]], dtype=uint8),
#  array([[[106, 104, 109],
#          [106, 104, 109],
#          [106, 104, 109],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[107, 105, 110],
#          [107, 105, 110],
#          [107, 105, 110],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[108, 106, 111],
#          [108, 106, 111],
#          [108, 106, 111],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         ...,
#
#         [[137, 132, 136],
#          [138, 133, 137],
#          [138, 133, 137],
#          ...,
#          [  7,   7,   7],
#          [  6,   6,   6],
#          [  6,   6,   6]],
#
#         [[137, 132, 136],
#          [137, 132, 136],
#          [138, 133, 137],
#          ...,
#          [  6,   6,   6],
#          [  6,   6,   6],
#          [  6,   6,   6]],
#
#         [[137, 132, 136],
#          [137, 132, 136],
#          [137, 132, 136],
#          ...,
#          [  6,   6,   6],
#          [  6,   6,   6],
#          [  6,   6,   6]]], dtype=uint8),
#  array([[[107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108],
#          ...,
#          [114, 112, 113],
#          [114, 112, 113],
#          [114, 112, 113]],
#
#         [[107, 105, 108],
#          [107, 105, 108],
#          [108, 106, 109],
#          ...,
#          [114, 112, 113],
#          [114, 112, 113],
#          [114, 112, 113]],
#
#         [[107, 105, 108],
#          [108, 106, 109],
#          [108, 106, 109],
#          ...,
#          [114, 112, 113],
#          [114, 112, 113],
#          [114, 112, 113]],
#
#         ...,
#
#         [[136, 135, 133],
#          [102, 101,  99],
#          [ 36,  35,  33],
#          ...,
#          [123, 121, 124],
#          [124, 122, 125],
#          [124, 122, 125]],
#
#         [[129, 128, 126],
#          [ 85,  84,  82],
#          [ 16,  15,  13],
#          ...,
#          [124, 122, 125],
#          [124, 122, 125],
#          [125, 123, 126]],
#
#         [[116, 115, 113],
#          [ 70,  69,  67],
#          [  4,   3,   1],
#          ...,
#          [124, 122, 125],
#          [124, 122, 125],
#          [125, 123, 126]]], dtype=uint8),
#  array([[[ 93,  91,  94],
#          [ 93,  91,  94],
#          [ 93,  91,  94],
#          ...,
#          [ 97,  95,  98],
#          [ 97,  95,  98],
#          [ 97,  95,  98]],
#
#         [[ 93,  91,  94],
#          [ 93,  91,  94],
#          [ 94,  92,  95],
#          ...,
#          [ 97,  95,  98],
#          [ 97,  95,  98],
#          [ 97,  95,  98]],
#
#         [[ 94,  92,  95],
#          [ 94,  92,  95],
#          [ 94,  92,  95],
#          ...,
#          [ 97,  95,  98],
#          [ 97,  95,  98],
#          [ 97,  95,  98]],
#
#         ...,
#
#         [[125, 107,  87],
#          [124, 106,  86],
#          [123, 105,  85],
#          ...,
#          [138, 132, 134],
#          [142, 137, 141],
#          [134, 129, 135]],
#
#         [[119, 101,  81],
#          [119, 101,  81],
#          [120, 102,  82],
#          ...,
#          [134, 128, 130],
#          [139, 134, 138],
#          [133, 128, 134]],
#
#         [[126, 108,  88],
#          [126, 108,  88],
#          [126, 108,  88],
#          ...,
#          [131, 125, 127],
#          [136, 131, 135],
#          [131, 126, 132]]], dtype=uint8),
#  array([[[121, 118, 125],
#          [121, 118, 125],
#          [121, 118, 125],
#          ...,
#          [126, 124, 129],
#          [126, 124, 129],
#          [126, 124, 129]],
#
#         [[121, 118, 125],
#          [121, 118, 125],
#          [122, 119, 126],
#          ...,
#          [126, 124, 129],
#          [126, 124, 129],
#          [126, 124, 129]],
#
#         [[122, 119, 126],
#          [122, 119, 126],
#          [122, 119, 126],
#          ...,
#          [127, 125, 130],
#          [126, 124, 129],
#          [126, 124, 129]],
#
#         ...,
#
#         [[  5,   4,   0],
#          [  5,   4,   0],
#          [  4,   3,   1],
#          ...,
#          [ 34,  32,  35],
#          [160, 158, 161],
#          [186, 184, 187]],
#
#         [[  5,   4,   0],
#          [  4,   3,   0],
#          [  3,   2,   0],
#          ...,
#          [ 18,  16,  19],
#          [134, 132, 135],
#          [189, 187, 190]],
#
#         [[  5,   4,   0],
#          [  4,   3,   0],
#          [  3,   2,   0],
#          ...,
#          [  8,   6,   9],
#          [116, 114, 117],
#          [191, 189, 192]]], dtype=uint8),
#  array([[[ 94,  92,  95],
#          [ 94,  92,  95],
#          [ 94,  92,  95],
#          ...,
#          [ 99,  97,  98],
#          [ 99,  97,  98],
#          [ 99,  97,  98]],
#
#         [[ 94,  92,  95],
#          [ 94,  92,  95],
#          [ 94,  92,  95],
#          ...,
#          [100,  98,  99],
#          [ 99,  97,  98],
#          [ 99,  97,  98]],
#
#         [[ 94,  92,  95],
#          [ 94,  92,  95],
#          [ 94,  92,  95],
#          ...,
#          [100,  98,  99],
#          [100,  98,  99],
#          [ 99,  97,  98]],
#
#         ...,
#
#         [[132, 130, 131],
#          [133, 131, 132],
#          [138, 136, 137],
#          ...,
#          [ 13,  12,  10],
#          [ 15,  14,  12],
#          [ 16,  15,  13]],
#
#         [[132, 130, 131],
#          [134, 132, 133],
#          [139, 137, 138],
#          ...,
#          [ 11,  10,   8],
#          [ 12,  11,   9],
#          [ 14,  13,  11]],
#
#         [[129, 127, 128],
#          [132, 130, 131],
#          [137, 135, 136],
#          ...,
#          [  9,   8,   6],
#          [ 11,  10,   8],
#          [ 12,  11,   9]]], dtype=uint8),
#  array([[[ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          ...,
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93]],
#
#         [[ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          ...,
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93]],
#
#         [[ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          ...,
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93]],
#
#         ...,
#
#         [[139, 136, 145],
#          [140, 137, 144],
#          [141, 139, 144],
#          ...,
#          [131, 130, 128],
#          [133, 131, 132],
#          [130, 128, 129]],
#
#         [[137, 134, 143],
#          [141, 138, 145],
#          [142, 140, 145],
#          ...,
#          [131, 130, 128],
#          [134, 132, 133],
#          [131, 129, 130]],
#
#         [[136, 133, 142],
#          [141, 138, 145],
#          [143, 141, 146],
#          ...,
#          [132, 131, 129],
#          [136, 134, 135],
#          [133, 131, 132]]], dtype=uint8),
#  array([[[ 94,  92,  97],
#          [ 96,  94,  99],
#          [ 99,  97, 102],
#          ...,
#          [112, 110, 115],
#          [108, 106, 111],
#          [103, 101, 106]],
#
#         [[ 94,  92,  97],
#          [ 96,  94,  99],
#          [ 99,  97, 102],
#          ...,
#          [112, 110, 115],
#          [109, 107, 112],
#          [103, 101, 106]],
#
#         [[ 94,  92,  97],
#          [ 97,  95, 100],
#          [ 99,  97, 102],
#          ...,
#          [112, 110, 115],
#          [109, 107, 112],
#          [103, 101, 106]],
#
#         ...,
#
#         [[129, 127, 130],
#          [134, 132, 135],
#          [137, 135, 138],
#          ...,
#          [ 93, 109, 124],
#          [ 57,  71,  84],
#          [ 26,  40,  53]],
#
#         [[129, 127, 130],
#          [134, 132, 135],
#          [137, 135, 138],
#          ...,
#          [ 78,  94, 109],
#          [ 44,  58,  71],
#          [ 18,  32,  45]],
#
#         [[129, 127, 130],
#          [134, 132, 135],
#          [137, 135, 138],
#          ...,
#          [ 68,  84,  99],
#          [ 46,  60,  73],
#          [ 29,  43,  56]]], dtype=uint8),
#  array([[[ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          ...,
#          [102, 100, 101],
#          [102, 100, 101],
#          [102, 100, 101]],
#
#         [[ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          ...,
#          [102, 100, 101],
#          [102, 100, 101],
#          [102, 100, 101]],
#
#         [[ 96,  94,  97],
#          [ 96,  94,  97],
#          [ 96,  94,  97],
#          ...,
#          [102, 100, 101],
#          [102, 100, 101],
#          [102, 100, 101]],
#
#         ...,
#
#         [[ 13,  12,   8],
#          [ 13,  12,   8],
#          [ 12,  11,   7],
#          ...,
#          [ 12,  12,  12],
#          [ 15,  15,  15],
#          [ 17,  17,  17]],
#
#         [[ 13,  12,   8],
#          [ 12,  11,   7],
#          [ 11,  10,   6],
#          ...,
#          [ 12,  12,  12],
#          [ 15,  15,  15],
#          [ 17,  17,  17]],
#
#         [[ 13,  12,   8],
#          [ 12,  11,   7],
#          [ 11,  10,   6],
#          ...,
#          [ 12,  12,  12],
#          [ 15,  15,  15],
#          [ 17,  17,  17]]], dtype=uint8),
#  array([[[ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         [[ 92,  90,  93],
#          [ 92,  90,  93],
#          [ 92,  90,  93],
#          ...,
#          [ 98,  96,  99],
#          [ 98,  96,  99],
#          [ 98,  96,  99]],
#
#         ...,
#
#         [[142, 137, 141],
#          [142, 137, 141],
#          [142, 137, 141],
#          ...,
#          [ 30,  25,  21],
#          [ 29,  24,  20],
#          [ 29,  24,  20]],
#
#         [[142, 137, 141],
#          [142, 137, 141],
#          [142, 137, 141],
#          ...,
#          [ 30,  25,  21],
#          [ 29,  24,  20],
#          [ 29,  24,  20]],
#
#         [[142, 137, 141],
#          [142, 137, 141],
#          [142, 137, 141],
#          ...,
#          [ 30,  25,  21],
#          [ 29,  24,  20],
#          [ 29,  24,  20]]], dtype=uint8),
#  array([[[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         ...,
#
#         [[142, 138, 139],
#          [145, 141, 142],
#          [141, 137, 136],
#          ...,
#          [129, 127, 130],
#          [129, 127, 128],
#          [129, 127, 128]],
#
#         [[134, 130, 131],
#          [136, 132, 133],
#          [128, 124, 123],
#          ...,
#          [129, 127, 130],
#          [129, 127, 128],
#          [129, 127, 128]],
#
#         [[140, 136, 137],
#          [140, 136, 137],
#          [131, 127, 126],
#          ...,
#          [129, 127, 130],
#          [129, 127, 128],
#          [129, 127, 128]]], dtype=uint8),
#  array([[[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         ...,
#
#         [[130, 131, 133],
#          [133, 134, 136],
#          [139, 140, 142],
#          ...,
#          [129, 127, 130],
#          [129, 127, 130],
#          [129, 127, 130]],
#
#         [[128, 129, 131],
#          [133, 134, 136],
#          [139, 140, 142],
#          ...,
#          [129, 127, 130],
#          [129, 127, 130],
#          [129, 127, 130]],
#
#         [[127, 128, 130],
#          [134, 135, 137],
#          [139, 140, 142],
#          ...,
#          [129, 127, 130],
#          [129, 127, 130],
#          [129, 127, 130]]], dtype=uint8),
#  array([[[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96]],
#
#         [[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96]],
#
#         [[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96]],
#
#         ...,
#
#         [[179, 154, 150],
#          [178, 153, 148],
#          [183, 156, 149],
#          ...,
#          [234, 211, 205],
#          [234, 211, 205],
#          [234, 211, 205]],
#
#         [[181, 153, 149],
#          [179, 151, 147],
#          [183, 154, 148],
#          ...,
#          [235, 212, 206],
#          [234, 211, 205],
#          [234, 211, 205]],
#
#         [[182, 154, 150],
#          [178, 150, 146],
#          [183, 154, 148],
#          ...,
#          [235, 212, 206],
#          [234, 211, 205],
#          [234, 211, 205]]], dtype=uint8)]

# %% [markdown]
# ## Prediction

# %%
feed = np.array(pre_process_image_data(mids24_path))
feed
# Out:
# array([[[[111, 109, 114],
#          [111, 109, 114],
#          [111, 109, 114],
#          ...,
#          [113, 111, 114],
#          [113, 111, 114],
#          [113, 111, 114]],
#
#         [[111, 109, 114],
#          [111, 109, 114],
#          [112, 110, 115],
#          ...,
#          [113, 111, 114],
#          [113, 111, 114],
#          [113, 111, 114]],
#
#         [[111, 109, 114],
#          [112, 110, 115],
#          [112, 110, 115],
#          ...,
#          [113, 111, 114],
#          [113, 111, 114],
#          [113, 111, 114]],
#
#         ...,
#
#         [[ 19,  23,  35],
#          [ 20,  24,  36],
#          [ 21,  25,  37],
#          ...,
#          [ 15,  24,  33],
#          [ 19,  28,  37],
#          [ 26,  35,  44]],
#
#         [[ 19,  23,  35],
#          [ 20,  24,  36],
#          [ 22,  26,  38],
#          ...,
#          [ 15,  24,  33],
#          [ 18,  27,  36],
#          [ 25,  34,  43]],
#
#         [[ 19,  23,  35],
#          [ 20,  24,  36],
#          [ 22,  26,  38],
#          ...,
#          [ 15,  24,  33],
#          [ 18,  27,  36],
#          [ 25,  34,  43]]],
#
#
#        [[[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         ...,
#
#         [[151, 143, 141],
#          [148, 140, 137],
#          [144, 134, 132],
#          ...,
#          [139, 132, 139],
#          [140, 130, 139],
#          [142, 135, 143]],
#
#         [[158, 148, 146],
#          [143, 134, 129],
#          [122, 111, 107],
#          ...,
#          [140, 130, 138],
#          [141, 129, 139],
#          [144, 134, 143]],
#
#         [[151, 142, 137],
#          [125, 116, 111],
#          [ 89,  78,  74],
#          ...,
#          [141, 130, 138],
#          [140, 128, 138],
#          [146, 134, 144]]],
#
#
#        [[[ 87,  85,  88],
#          [ 87,  85,  88],
#          [ 87,  85,  88],
#          ...,
#          [ 97,  95,  96],
#          [ 97,  95,  96],
#          [ 97,  95,  96]],
#
#         [[ 87,  85,  88],
#          [ 87,  85,  88],
#          [ 88,  86,  89],
#          ...,
#          [ 97,  95,  96],
#          [ 97,  95,  96],
#          [ 97,  95,  96]],
#
#         [[ 88,  86,  89],
#          [ 88,  86,  89],
#          [ 88,  86,  89],
#          ...,
#          [ 97,  95,  96],
#          [ 97,  95,  96],
#          [ 97,  95,  96]],
#
#         ...,
#
#         [[142, 138, 135],
#          [164, 161, 156],
#          [189, 186, 179],
#          ...,
#          [244, 243, 238],
#          [247, 246, 241],
#          [245, 244, 239]],
#
#         [[146, 143, 138],
#          [178, 175, 170],
#          [193, 190, 183],
#          ...,
#          [244, 243, 238],
#          [248, 247, 242],
#          [244, 243, 238]],
#
#         [[150, 147, 142],
#          [188, 185, 180],
#          [195, 192, 185],
#          ...,
#          [245, 244, 239],
#          [248, 247, 242],
#          [243, 242, 237]]],
#
#
#        ...,
#
#
#        [[[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         [[104, 102, 105],
#          [104, 102, 105],
#          [104, 102, 105],
#          ...,
#          [107, 105, 108],
#          [107, 105, 108],
#          [107, 105, 108]],
#
#         ...,
#
#         [[142, 138, 139],
#          [145, 141, 142],
#          [141, 137, 136],
#          ...,
#          [129, 127, 130],
#          [129, 127, 128],
#          [129, 127, 128]],
#
#         [[134, 130, 131],
#          [136, 132, 133],
#          [128, 124, 123],
#          ...,
#          [129, 127, 130],
#          [129, 127, 128],
#          [129, 127, 128]],
#
#         [[140, 136, 137],
#          [140, 136, 137],
#          [131, 127, 126],
#          ...,
#          [129, 127, 130],
#          [129, 127, 128],
#          [129, 127, 128]]],
#
#
#        [[[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         [[101,  99, 102],
#          [101,  99, 102],
#          [101,  99, 102],
#          ...,
#          [102, 100, 103],
#          [102, 100, 103],
#          [102, 100, 103]],
#
#         ...,
#
#         [[130, 131, 133],
#          [133, 134, 136],
#          [139, 140, 142],
#          ...,
#          [129, 127, 130],
#          [129, 127, 130],
#          [129, 127, 130]],
#
#         [[128, 129, 131],
#          [133, 134, 136],
#          [139, 140, 142],
#          ...,
#          [129, 127, 130],
#          [129, 127, 130],
#          [129, 127, 130]],
#
#         [[127, 128, 130],
#          [134, 135, 137],
#          [139, 140, 142],
#          ...,
#          [129, 127, 130],
#          [129, 127, 130],
#          [129, 127, 130]]],
#
#
#        [[[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96]],
#
#         [[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96]],
#
#         [[ 90,  88,  91],
#          [ 90,  88,  91],
#          [ 90,  88,  91],
#          ...,
#          [ 95,  93,  96],
#          [ 95,  93,  96],
#          [ 95,  93,  96]],
#
#         ...,
#
#         [[179, 154, 150],
#          [178, 153, 148],
#          [183, 156, 149],
#          ...,
#          [234, 211, 205],
#          [234, 211, 205],
#          [234, 211, 205]],
#
#         [[181, 153, 149],
#          [179, 151, 147],
#          [183, 154, 148],
#          ...,
#          [235, 212, 206],
#          [234, 211, 205],
#          [234, 211, 205]],
#
#         [[182, 154, 150],
#          [178, 150, 146],
#          [183, 154, 148],
#          ...,
#          [235, 212, 206],
#          [234, 211, 205],
#          [234, 211, 205]]]], dtype=uint8)

# %%
# predict the mids24 data
import os
# mids24_data = []
# for i in os.listdir(mids24_path):
#     if i.endswith(".jpg"):
#         img = Image.open(mids24_path + "/" + i)
#         img = np.array(img)
#         mids24_data.append(img)

# convert the list to numpy array
# mids24_data = np.array(mids24_data)

# predict the mids24 data
mids24_pred = model.predict(feed.reshape(-1, 256, 256, 3))

# # save the prediction result
result1 = np.save("mids24_pred.npy", mids24_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 14
#       2 import os
#       3 # mids24_data = []
#       4 # for i in os.listdir(mids24_path):
#       5 #     if i.endswith(".jpg"):
#    (...)
#      12
#      13 # predict the mids24 data
# ---> 14 mids24_pred = model.predict(feed.reshape(-1, 256, 256, 3))
#      16 # # save the prediction result
#      17 result1 = np.save("mids24_pred.npy", mids24_pred)
#
# NameError: name 'model' is not defined

# %%
# get the prediction result
mids24_pred = np.load("mids24_pred.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 # get the prediction result
# ----> 2 mids24_pred = np.load("mids24_pred.npy")
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mids24_pred.npy'

# %%
os.listdir(mids24_path)
# Out:
# ['Yuanjing-Zhu-400x400.jpeg',
#  'Beibei-Bella-Du-400x400.jpeg',
#  'Zhonglin-Wang-400x400.jpeg',
#  'Zhanyi-Lin-400x400.jpeg',
#  'Dingkun-Yang-400x400.jpeg',
#  'Dany-Jabban-400x400.jpeg',
#  'Echo-Chen-400x400.jpeg',
#  'Xiaoquan-Liu-400x400.jpeg',
#  'Andrew-Kroening-400x400.jpeg',
#  'Suzy-Anil-400x400.jpeg',
#  'Suzanna-Thompson-400x400.jpeg',
#  'Genesis-Qu-400x400.jpeg',
#  'Song-Young-Oh-400x400.jpeg',
#  'Alisa-Tian-400x400.jpeg',
#  'Heather-Qiu-400x400.jpeg',
#  'Emma-Wang-400x400.jpeg',
#  'Aditya-John-400x400.jpeg',
#  'Eric-Rios-Soderman-400x400.jpeg',
#  'Kashaf-Ali-400x400.jpeg',
#  'luo-400x398.jpeg',
#  'Scott-Lai-400x400.jpeg',
#  'Emmanuel-Ruhamyankaka-400x400.jpeg',
#  'Pooja-Kabber-400x400.jpeg',
#  'Sukhpreet-Sahota-400x400.jpeg',
#  'Ahmed-Ibrahim-400x400.jpeg',
#  'Isha-Singh-400x400.jpeg',
#  'Kristi-Van-Meter-400x400.jpeg',
#  'Pragya-Raghuvanshi-400x400.jpeg',
#  'Chloe-Liu-400x400.jpeg',
#  'Ya-Yun-Huang-400x400.jpeg',
#  'Wafiakmal-Miftah-400x400.jpeg',
#  'Pomelo-Wu-400x400.jpeg',
#  'README.md',
#  'Jenny-Shen-400x400.jpeg',
#  'Paul-Mckee-400x400.jpeg',
#  'Lorna-Aine-400x400.jpeg',
#  'Elisa-Chen-400x400.jpeg',
#  'Jiaxin-Ying-400x400.jpeg',
#  'Nick-Carroll-400x400.jpeg']

# %%
def get_path(path):
    img_path = []
    for i in os.listdir(path):
        # print(i)
        if i[-4:] == "jpeg":
        # print(path + str('/' + i))
            with open(path + str('/' + i), 'rb') as f:
                img_path.append(path + str('/' + i))
    return img_path

get_path(mids24_path)
# Out:
# ['/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Yuanjing-Zhu-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Beibei-Bella-Du-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Zhonglin-Wang-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Zhanyi-Lin-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Dingkun-Yang-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Dany-Jabban-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Echo-Chen-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Xiaoquan-Liu-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Andrew-Kroening-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Suzy-Anil-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Suzanna-Thompson-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Genesis-Qu-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Song-Young-Oh-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Alisa-Tian-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Heather-Qiu-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Emma-Wang-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Aditya-John-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Eric-Rios-Soderman-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Kashaf-Ali-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/luo-400x398.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Scott-Lai-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Emmanuel-Ruhamyankaka-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Pooja-Kabber-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Sukhpreet-Sahota-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Ahmed-Ibrahim-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Isha-Singh-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Kristi-Van-Meter-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Pragya-Raghuvanshi-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Chloe-Liu-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Ya-Yun-Huang-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Wafiakmal-Miftah-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Pomelo-Wu-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Jenny-Shen-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Paul-Mckee-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Lorna-Aine-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Elisa-Chen-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Jiaxin-Ying-400x400.jpeg',
#  '/workspaces/IDS705_ML_Team9/Data/Application/MIDS24/Nick-Carroll-400x400.jpeg']

# %%
len(mids24_pred)
# create a dataframe to store the prediction result and the image name
mids24_pred_df = pd.DataFrame(mids24_pred, columns=["pred"])
mids24_pred_df["image_name"] = get_path(mids24_path)
mids24_pred_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 len(mids24_pred)
#       2 # create a dataframe to store the prediction result and the image name
#       3 mids24_pred_df = pd.DataFrame(mids24_pred, columns=["pred"])
#
# NameError: name 'mids24_pred' is not defined

# %%
mids24_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mids24_pred
#
# NameError: name 'mids24_pred' is not defined

# %%
# get valuecounts of the prediction result
mids24_pred_df["pred"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # get valuecounts of the prediction result
# ----> 2 mids24_pred_df["pred"].value_counts()
#
# NameError: name 'mids24_pred_df' is not defined

# %% [markdown]
# ## process zip file

# %%
real_ai_path = "/workspaces/IDS705_ML_Team9/Data/Application/very_real_ai-faces-20230417T184918Z-001.zip"

# unzip the file
import zipfile
with zipfile.ZipFile(real_ai_path, 'r') as zip_ref:
    zip_ref.extractall("/workspaces/IDS705_ML_Team9/Data/Application/very_real_ai-faces")

# %%
new_path = "/workspaces/IDS705_ML_Team9/Data/Application/Application_Dating_Profile"

# use function to pre-process the image data
pre_process_image_data(new_path)

from PIL import Image
def pre_process_image_data(path):
    lst_img = []
    for i in os.listdir(path):
        # print(i)
        if i[-3:] == "jpg":
        # print(path + str('/' + i))
            with open(path + str('/' + i), 'rb') as f:
                img = Image.open(f)
                # resize the image to 256 by 256
                img = img.resize((256, 256))
                # save it to the same folder and overwrite the original
                img.save(path + str('/' + i))
                # print("saved")
                # store their array in a list
                lst_img.append(np.array(img))
    return lst_img
pre_process_image_data(new_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/PIL/JpegImagePlugin.py:640, in _save(im, fp, filename)
#     639 try:
# --> 640     rawmode = RAWMODE[im.mode]
#     641 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[36], line 23
#      21                 lst_img.append(np.array(img))
#      22     return lst_img
# ---> 23 pre_process_image_data(new_path)
#
# Cell In[36], line 18, in pre_process_image_data(path)
#      16 img = img.resize((256, 256))
#      17 # save it to the same folder and overwrite the original
# ---> 18 img.save(path + str('/' + i))
#      19 # print("saved")
#      20 # store their array in a list
#      21 lst_img.append(np.array(img))
#
# File ~/.local/lib/python3.10/site-packages/PIL/Image.py:2432, in Image.save(self, fp, format, **params)
#    2429         fp = builtins.open(filename, "w+b")
#    2431 try:
# -> 2432     save_handler(self, fp, filename)
#    2433 except Exception:
#    2434     if open_fp:
#
# File ~/.local/lib/python3.10/site-packages/PIL/JpegImagePlugin.py:643, in _save(im, fp, filename)
#     641 except KeyError as e:
#     642     msg = f"cannot write mode {im.mode} as JPEG"
# --> 643     raise OSError(msg) from e
#     645 info = im.encoderinfo
#     647 dpi = [round(x) for x in info.get("dpi", (0, 0))]
#
# OSError: cannot write mode RGBA as JPEG
