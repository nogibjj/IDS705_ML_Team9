# %%
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
# Out:
# 2023-04-03 03:10:05.578034: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-03 03:10:05.624966: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-03 03:10:05.625820: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 03:10:06.449122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
img = load_img("Data/Train/00001.png", target_size = (128, 128))
plt.imshow(img)

# %%
from PIL import Image
image = Image.open("Data/Train/00000.png")
image = image.resize((224, 224))

# %%
# check input shape
img_array = img_to_array(image)
img_array.shape
# Out:
# (224, 224, 3)

# %%
image = np.expand_dims(image, axis=0)
image.shape
# Out:
# (1, 224, 224, 3)

# %%
image = preprocess_input(image)

# %%
import numpy as np
image = np.reshape(image, (-1, 224, 224, 3))

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
model = ResNet50(weights="imagenet")

# %%
# predict the probability across all output classes
preds = model.predict(image)
# Out:
# 1/1 [==============================] - 1s 827ms/step

# %%
print("Predicted:", decode_predictions(preds, top=1)[0])
# Out:
# Predicted: [('n03131574', 'crib', 0.3323865)]
