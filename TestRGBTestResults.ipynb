# %%
"""Resnet model for classification of real and fake images."""
import os
import matplotlib.pyplot as plt
import numpy as np
import glob
import PIL as image_lib
import tensorflow as tflow
from tensorflow.keras.layers import Flatten
from keras.layers.core import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from PIL import Image
import matplotlib.pyplot as plotter_lib
import numpy as np
import PIL as image_lib
import tensorflow as tflow
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.layers import Flatten
from keras.layers.core import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import time
import gc
from PIL import Image
# Timing the script

script_time = time.time()

# %%
AUTOTUNE = tflow.data.AUTOTUNE

# %%
IMAGE_SIZE = (256, 256)  # height, width
batch_size = 128  # 32 is default recommendation for vision models

# %%
train_ds = tflow.keras.preprocessing.image_dataset_from_directory(
    "T9-Train",
    label_mode="binary",
    # validation_split=val_ratio,
    shuffle=True,
    # subset="training",
    seed=417,
    image_size=IMAGE_SIZE,
    batch_size=batch_size,  # Changed from batch_size 32 to none
    # color_mode="grayscale",
)
# Out:
# Found 100796 files belonging to 2 classes.

# %%
validation_ds = tflow.keras.preprocessing.image_dataset_from_directory(
    "T9-Val",
    # validation_split=val_ratio,
    shuffle=True,
    # subset="validation",
    seed=417,
    label_mode="binary",
    image_size=IMAGE_SIZE,
    batch_size=batch_size,  # Changed from batch_size 32 to none
    # color_mode="grayscale",
)
# Out:
# Found 11200 files belonging to 2 classes.

# %%
train_ds_and_val_ds = train_ds.concatenate(validation_ds)

# %%
count = 0
img_gs = []
label_gs = []
for img, label in train_ds_and_val_ds.take(-1):
    count += 1
    img_gs.append(img.numpy())
    label_gs.append(label.numpy())

print(f"Number of batches in TrainplusVal: {count}")
# Out:
# Number of batches in TrainplusVal: 876

# %%
train_ds_and_val_ds.shuffle(count, reshuffle_each_iteration=False)
del count, img_gs, label_gs
gc.collect()
# Out:
# 0

# %%
test_ds = tflow.keras.preprocessing.image_dataset_from_directory(
    "T9-Test",
    label_mode="binary",
    shuffle=True,
    seed=417,
    image_size=IMAGE_SIZE,
    batch_size=batch_size,  # Changed from batch_size 32 to none
    # color_mode="grayscale",
)
# Out:
# Found 28000 files belonging to 2 classes.

# %%
epochs = 10

# %%
demo_resnet_model = tflow.keras.models.load_model("demo_resnet_model_140K.h5")

# %%
history = demo_resnet_model.fit(
    train_ds_and_val_ds,
    # validation_data=validation_ds,
    epochs=epochs,
    verbose=1,
    shuffle=False,  # For reproducibility
    # callbacks=[tflow.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)],
)
# Out:
# Epoch 1/10
# 876/876 [==============================] - 227s 252ms/step - loss: 0.0629 - accuracy: 0.9766 - auc: 0.9972 - precision: 0.9783 - recall: 0.9748 - true_positives: 54586.0000 - true_negatives: 54786.0000 - false_positives: 1211.0000 - false_negatives: 1413.0000
# Epoch 2/10
# 876/876 [==============================] - 234s 267ms/step - loss: 0.0584 - accuracy: 0.9784 - auc: 0.9976 - precision: 0.9798 - recall: 0.9769 - true_positives: 54705.0000 - true_negatives: 54869.0000 - false_positives: 1128.0000 - false_negatives: 1294.0000
# Epoch 3/10
# 876/876 [==============================] - 234s 267ms/step - loss: 0.0452 - accuracy: 0.9836 - auc: 0.9985 - precision: 0.9847 - recall: 0.9824 - true_positives: 55013.0000 - true_negatives: 55142.0000 - false_positives: 855.0000 - false_negatives: 986.0000
# Epoch 4/10
# 876/876 [==============================] - 234s 267ms/step - loss: 0.0415 - accuracy: 0.9849 - auc: 0.9988 - precision: 0.9858 - recall: 0.9839 - true_positives: 55097.0000 - true_negatives: 55204.0000 - false_positives: 793.0000 - false_negatives: 902.0000
# Epoch 5/10
# 876/876 [==============================] - 233s 266ms/step - loss: 0.0354 - accuracy: 0.9869 - auc: 0.9992 - precision: 0.9880 - recall: 0.9858 - true_positives: 55206.0000 - true_negatives: 55327.0000 - false_positives: 670.0000 - false_negatives: 793.0000
# Epoch 6/10
# 876/876 [==============================] - 234s 267ms/step - loss: 0.0353 - accuracy: 0.9869 - auc: 0.9991 - precision: 0.9880 - recall: 0.9858 - true_positives: 55205.0000 - true_negatives: 55328.0000 - false_positives: 669.0000 - false_negatives: 794.0000
# Epoch 7/10
# 876/876 [==============================] - 238s 271ms/step - loss: 0.0285 - accuracy: 0.9899 - auc: 0.9994 - precision: 0.9910 - recall: 0.9889 - true_positives: 55377.0000 - true_negatives: 55493.0000 - false_positives: 504.0000 - false_negatives: 622.0000
# Epoch 8/10
# 876/876 [==============================] - 238s 272ms/step - loss: 0.0311 - accuracy: 0.9882 - auc: 0.9993 - precision: 0.9892 - recall: 0.9870 - true_positives: 55273.0000 - true_negatives: 55396.0000 - false_positives: 601.0000 - false_negatives: 726.0000
# Epoch 9/10
# 876/876 [==============================] - 236s 269ms/step - loss: 0.0253 - accuracy: 0.9907 - auc: 0.9996 - precision: 0.9910 - recall: 0.9903 - true_positives: 55455.0000 - true_negatives: 55495.0000 - false_positives: 502.0000 - false_negatives: 544.0000
# Epoch 10/10
# 876/876 [==============================] - 225s 257ms/step - loss: 0.0240 - accuracy: 0.9914 - auc: 0.9996 - precision: 0.9921 - recall: 0.9906 - true_positives: 55472.0000 - true_negatives: 55557.0000 - false_positives: 440.0000 - false_negatives: 527.0000

# %%
demo_resnet_model.save("demo_resnet_model_140K_tr_val_rgb.h5")
demo_resnet_model.save_weights("demo_resnet_model_140K_tr_val_rgb_weights.h5")

# %%
ims = []
labs = []
probs = []
preds = []

# %%
ims = []
labs = []
probs = []
preds = []
for image, label in test_ds:
    ims.append(image)
    labs.append(label)
    probs.append(demo_resnet_model.predict(image))
    preds.append(np.round(demo_resnet_model.predict(image)))

ims = np.concatenate(ims, axis=0)
labs = np.concatenate(labs, axis=0)
probs = np.concatenate(probs, axis=0)
preds = np.concatenate(preds, axis=0)
misclassifieds = np.where(labs != preds)[0]
misc_ims = ims[misclassifieds]
misc_labs = labs[misclassifieds]
im_labels = zip(misc_ims, misc_labs)
# Out:
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 70ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 70ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 70ms/step
# 4/4 [==============================] - 0s 72ms/step
# 4/4 [==============================] - 0s 71ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 66ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 65ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 60ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 63ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 64ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 61ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 62ms/step
# 4/4 [==============================] - 0s 61ms/step
# 3/3 [==============================] - 0s 63ms/step
# 3/3 [==============================] - 0s 63ms/step

# %%
iter_for_name = 0
for im, lab in im_labels:
    if lab == 0:
        flag = "Fake"
    else:
        flag = "Real"
    reconstructed_image = Image.fromarray((im * 1).astype(np.uint8)).convert("RGB")
    # use old ind for naming
    reconstructed_image.save(f"T9-Misc140KRGB\{flag}\{flag}{iter_for_name}.png")
    iter_for_name += 1

# %%
print(f"Number of misclassified images in the test set: {len(misc_labs)}")
# Out:
# Number of misclassified images in the test set: 1290

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(labs, preds))
print(confusion_matrix(labs, preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95     14000
#          1.0       0.94      0.97      0.95     14000
#
#     accuracy                           0.95     28000
#    macro avg       0.95      0.95      0.95     28000
# weighted avg       0.95      0.95      0.95     28000
#
# [[13126   874]
#  [  416 13584]]

# %%
with open("test_classification_report.txt", "w") as f:
    f.write(str(classification_report(labs, preds)))
    f.close()

# %%
with open("test_confusion_matrix.txt", "w") as f:
    f.write(str(confusion_matrix(labs, preds)))
    f.close()

# %%
print(classification_report(labs, preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95     14000
#          1.0       0.94      0.97      0.95     14000
#
#     accuracy                           0.95     28000
#    macro avg       0.95      0.95      0.95     28000
# weighted avg       0.95      0.95      0.95     28000

# %%
print(confusion_matrix(labs, preds))
# Out:
# [[13126   874]
#  [  416 13584]]

# %%
import matplotlib.pyplot as plotter_lib
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import numpy as np

# %%
def roc_curve_T9(labels_ls, test_ds_pred):
    fpr, tpr, _ = roc_curve(labels_ls, test_ds_pred)
    auc_score = auc(fpr, tpr)
    # plot roc curve
    plotter_lib.plot(
        fpr,
        tpr,
        color="orange",
        label=f"ResNet50 (AUC = {auc_score:.3f})",
    )
    # axis labels
    # add random guessing line
    plotter_lib.plot([0, 1], [0, 1], color="darkblue", linestyle="--")
    plotter_lib.xlabel("False Positive Rate")
    plotter_lib.ylabel("True Positive rate")
    plotter_lib.legend(loc="best")
    plotter_lib.title("ROC Curve on Test Set")
    plotter_lib.show()
    plt.savefig("TestROC_curve.png")

# %%
roc_curve_T9(labs, probs)

# %%
def roc_curve_T9(labels_ls, test_ds_pred):
    fpr, tpr, _ = roc_curve(labels_ls, test_ds_pred)
    auc_score = auc(fpr, tpr)
    # plot roc curve
    plotter_lib.plot(
        fpr,
        tpr,
        color="orange",
        label=f"ResNet50 (AUC = {auc_score:.4f})",
    )
    # axis labels
    # add random guessing line
    plotter_lib.plot([0, 1], [0, 1], color="darkblue", linestyle="--")
    plotter_lib.xlabel("False Positive Rate")
    plotter_lib.ylabel("True Positive rate")
    plotter_lib.legend(loc="best")
    plotter_lib.title("ROC Curve on Test Set")
    plotter_lib.show()

# %%
roc_curve_T9(labs, probs)

# %%
from sklearn.metrics import average_precision_score

# %%
def pr_curve_T9(labels_ls, test_ds_pred):
    # calculate the no skill line as the proportion of the positive class
    no_skill = len(labels_ls[labels_ls == 1]) / len(labels_ls)
    # calculate model precision-recall curve
    precision, recall, _ = precision_recall_curve(labels_ls, test_ds_pred)
    # average precision score
    ap = average_precision_score(labels_ls, test_ds_pred)
    # plot the precision-recall curves
    plotter_lib.plot([0, 1], [no_skill, no_skill], linestyle="--", label="Random Chance")
    plotter_lib.plot(recall, precision, marker=".", label="ResNet50 (AP = %.4f)" % ap)
    # axis labels
    plotter_lib.xlabel("Recall")
    plotter_lib.ylabel("Precision")
    plotter_lib.title("Precision-Recall Curve on Test Set")
    plotter_lib.legend()
    plotter_lib.show()

# %%
pr_curve_T9(labs, probs)

# %%
evaluation = demo_resnet_model.evaluate(test_ds, verbose=1, return_dict=True)
print(evaluation)
# write evaluation to file

with open("test_evaluation.txt", "w") as f:
    f.write(str(evaluation))
    f.write(str(test_ds.class_names))
    f.close()
# Out:
# 219/219 [==============================] - 62s 273ms/step - loss: 0.1539 - accuracy: 0.9539 - auc: 0.9877 - precision: 0.9395 - recall: 0.9702 - true_positives: 13583.0000 - true_negatives: 13126.0000 - false_positives: 874.0000 - false_negatives: 417.0000
# {'loss': 0.15392383933067322, 'accuracy': 0.9538928866386414, 'auc': 0.9876847267150879, 'precision': 0.9395448565483093, 'recall': 0.970214307308197, 'true_positives': 13583.0, 'true_negatives': 13126.0, 'false_positives': 874.0, 'false_negatives': 417.0}

# %%
evaluation
# Out:
# {'loss': 0.15392383933067322,
#  'accuracy': 0.9538928866386414,
#  'auc': 0.9876847267150879,
#  'precision': 0.9395448565483093,
#  'recall': 0.970214307308197,
#  'true_positives': 13583.0,
#  'true_negatives': 13126.0,
#  'false_positives': 874.0,
#  'false_negatives': 417.0}

# %%
demo_resnet_model.save("TrainValmodel/demo_resnet_model_140K_tr_val_rgb")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: TrainValmodel/demo_resnet_model_140K_tr_val_rgb\assets
# INFO:tensorflow:Assets written to: TrainValmodel/demo_resnet_model_140K_tr_val_rgb\assets

# %%
demo_resnet_model.optimizer

# %%
demo_resnet_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 24,637,313
# Trainable params: 1,049,601
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
demo_resnet_model.save("demo_resnet_model_140K_tr_val_rgb.h5")
demo_resnet_model.save_weights("demo_resnet_model_140K_tr_val_rgb_weights.h5")

# %%
all_ds = train_ds_and_val_ds.concatenate(test_ds)

# %%
count = 0
for  im, label in all_ds.take(-1):
    count += im.shape[0]

# %%
print("The images in the dataset with all the data are: ", count)
# Out:
# The images in the dataset with all the data are:  139996

# %%
final_history = demo_resnet_model.fit(
    all_ds,
    # validation_data=validation_ds,
    epochs=epochs,
    verbose=1,
    shuffle=False,  # For reproducibility
    # callbacks=[tflow.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)],
)
# Out:
# Epoch 1/10
# 1095/1095 [==============================] - 300s 273ms/step - loss: 0.0557 - accuracy: 0.9810 - auc: 0.9972 - precision: 0.9814 - recall: 0.9805 - true_positives: 68636.0000 - true_negatives: 68696.0000 - false_positives: 1301.0000 - false_negatives: 1363.0000
# Epoch 2/10
# 1095/1095 [==============================] - 298s 272ms/step - loss: 0.0443 - accuracy: 0.9840 - auc: 0.9982 - precision: 0.9850 - recall: 0.9830 - true_positives: 68812.0000 - true_negatives: 68951.0000 - false_positives: 1046.0000 - false_negatives: 1187.0000
# Epoch 3/10
# 1095/1095 [==============================] - 298s 272ms/step - loss: 0.0359 - accuracy: 0.9874 - auc: 0.9988 - precision: 0.9880 - recall: 0.9868 - true_positives: 69075.0000 - true_negatives: 69161.0000 - false_positives: 836.0000 - false_negatives: 924.0000
# Epoch 4/10
# 1095/1095 [==============================] - 298s 272ms/step - loss: 0.0323 - accuracy: 0.9887 - auc: 0.9991 - precision: 0.9895 - recall: 0.9879 - true_positives: 69152.0000 - true_negatives: 69261.0000 - false_positives: 736.0000 - false_negatives: 847.0000
# Epoch 5/10
# 1095/1095 [==============================] - 300s 273ms/step - loss: 0.0269 - accuracy: 0.9904 - auc: 0.9993 - precision: 0.9909 - recall: 0.9900 - true_positives: 69298.0000 - true_negatives: 69358.0000 - false_positives: 639.0000 - false_negatives: 701.0000
# Epoch 6/10
# 1095/1095 [==============================] - 300s 274ms/step - loss: 0.0254 - accuracy: 0.9909 - auc: 0.9994 - precision: 0.9915 - recall: 0.9903 - true_positives: 69318.0000 - true_negatives: 69400.0000 - false_positives: 597.0000 - false_negatives: 681.0000
# Epoch 7/10
# 1095/1095 [==============================] - 289s 264ms/step - loss: 0.0197 - accuracy: 0.9928 - auc: 0.9997 - precision: 0.9933 - recall: 0.9924 - true_positives: 69469.0000 - true_negatives: 69525.0000 - false_positives: 472.0000 - false_negatives: 530.0000
# Epoch 8/10
# 1095/1095 [==============================] - 283s 258ms/step - loss: 0.0215 - accuracy: 0.9921 - auc: 0.9996 - precision: 0.9924 - recall: 0.9918 - true_positives: 69427.0000 - true_negatives: 69467.0000 - false_positives: 530.0000 - false_negatives: 572.0000
# Epoch 9/10
# 1095/1095 [==============================] - 278s 253ms/step - loss: 0.0205 - accuracy: 0.9925 - auc: 0.9996 - precision: 0.9929 - recall: 0.9921 - true_positives: 69444.0000 - true_negatives: 69501.0000 - false_positives: 496.0000 - false_negatives: 555.0000
# Epoch 10/10
# 1095/1095 [==============================] - 272s 248ms/step - loss: 0.0189 - accuracy: 0.9931 - auc: 0.9997 - precision: 0.9934 - recall: 0.9927 - true_positives: 69491.0000 - true_negatives: 69534.0000 - false_positives: 463.0000 - false_negatives: 508.0000

# %%
demo_resnet_model.save("deploy_resnet_model_140K_alldata_rgb.h5")

# %%
demo_resnet_model.save_weights("deploy_resnet_model_140K_alldata_rgb_weights.h5")
